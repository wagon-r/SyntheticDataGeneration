# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_parquet(f"../../data/preprocessed/v6-train.parquet")
test = pd.read_parquet(f"../../data/synthesized/v6-test.parquet")
train.head()
# Out:
#    doorcyclecounter  misalignment_cd_vs_ld  cmcouplerfriction  cmdoorfriction  \
# 0              1166                    1.0         154.899994      121.300003
# 1              1167                    1.0         134.399994      120.699997
# 2              1168                    1.0         146.600006      119.800003
# 3              1169                    1.0         145.800003      122.000000
# 4              1170                    1.0         146.100006      120.400002
#
#    cmelectronicage  cmvibration  \
# 0             0.86          0.9
# 1             0.85          0.7
# 2             0.85          0.9
# 3             0.86          0.8
# 4             0.85          0.7
#
#                                            doorforce  \
# 0  [-75.0999984741211, -51.900001525878906, -48.0...
# 1  [-75.0999984741211, -92.0999984741211, -50.0, ...
# 2  [-75.0999984741211, -88.30000305175781, -50.20...
# 3  [-75.0999984741211, -83.4000015258789, -50.400...
# 4  [-75.0999984741211, -91.4000015258789, -49.200...
#
#                                            doorspeed  \
# 0  [0.0015999999595806003, 0.05310000106692314, 0...
# 1  [0.0015999999595806003, 0.0015999999595806003,...
# 2  [0.0015999999595806003, 0.0015999999595806003,...
# 3  [0.0015999999595806003, 0.0015999999595806003,...
# 4  [0.0015999999595806003, 0.0015999999595806003,...
#
#                                         doorposition
# 0  [-0.04919999837875366, -0.045099999755620956, ...
# 1  [-0.04919999837875366, -0.04919999837875366, -...
# 2  [-0.04919999837875366, -0.04919999837875366, -...
# 3  [-0.04919999837875366, -0.04919999837875366, -...
# 4  [-0.04919999837875366, -0.04919999837875366, -...

# %%
def combine_time_state_columns(df):
    """
    Combine columns with prefixes 'doorforce_', 'doorspeed_', and 'doorposition_'
    into arrays and replace the original columns with these new array columns.

    Parameters:
    df (pd.DataFrame): The input dataframe with time-state columns.

    Returns:
    pd.DataFrame: The dataframe with combined array columns.
    """
    # Identify columns with specific prefixes
    doorforce_columns = [col for col in df.columns if col.startswith('doorforce_')]
    doorspeed_columns = [col for col in df.columns if col.startswith('doorspeed_')]
    doorposition_columns = [col for col in df.columns if col.startswith('doorposition_')]

    # Combine columns into arrays
    df['doorforce'] = df[doorforce_columns].values.tolist()
    df['doorspeed'] = df[doorspeed_columns].values.tolist()
    df['doorposition'] = df[doorposition_columns].values.tolist()

    # Drop the original columns
    df = df.drop(columns=doorforce_columns + doorspeed_columns + doorposition_columns)

    return df

# Example usage
# Assuming 'train' is the dataframe loaded as described
# train = pd.read_parquet("../../data/preprocessed/v6-truncated-20ts.parquet")
# modified_train = combine_time_state_columns(train)
# print(modified_train)

# %%
postprocessed_train = combine_time_state_columns(train)
postprocessed_test = combine_time_state_columns(test)

postprocessed_train.to_parquet("../../data/preprocessed/v-train.parquet")
postprocessed_test.to_parquet("../../data/synthesized/v-test.parquet")
