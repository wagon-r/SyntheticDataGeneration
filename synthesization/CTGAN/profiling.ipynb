# %% [markdown]
# This script is used to compare the original data with the synthesized data
# The original data is stored in data/preprocessed/group_1.parquet
# The synthesized data is stored in data/synthesized/versuch2/{group_number}.parquet
# The comparison is stored in comparison_versuch{group_number}.html
# Source: https://docs.profiling.ydata.ai/latest/features/comparing_datasets/

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
postprocessed_train = pd.read_parquet(f"../../data/preprocessed/v6-train.parquet")
train_df = postprocessed_train.iloc[:100]
train_report = ProfileReport(train_df, title="Original")

# %%
postprocessed_test = pd.read_parquet(f"../../data/synthesized/v6-test.parquet")
test_df = postprocessed_test.iloc[:100]
test_report = ProfileReport(test_df, title="Synthetic")

# %%
test_df
# Out:
#     doorcyclecounter  cd_counter_rollers_installation  \
# 0        7262.498547                        -0.596375
# 1        4042.711550                         0.008071
# 2        2765.663085                         0.750673
# 3        4406.834136                        -0.002706
# 4        5071.028897                         0.579572
# ..               ...                              ...
# 95       2015.709356                        -1.006918
# 96       2625.366464                        -0.614927
# 97       4618.007610                         0.001914
# 98        353.338599                         1.050225
# 99       5226.904480                        -0.000243
#
#     ld_counter_rollers_installation  closing_device_failure  \
# 0                          0.010664                    True
# 1                         -0.016429                    True
# 2                         -0.012244                    True
# 3                          0.017069                    True
# 4                         -0.005455                    True
# ..                              ...                     ...
# 95                        -1.005305                    True
# 96                        -1.025100                    True
# 97                        -1.001648                    True
# 98                         0.968731                    True
# 99                        -1.154947                    True
#
#     misalignment_cd_vs_ld  misalignment_cd_vs_ld_sill_gap  belt_tension  \
# 0               -1.081079                       -0.003695      1.029177
# 1                0.011257                        1.112323      0.862966
# 2               -0.954111                        0.007764     -0.012745
# 3                0.011798                       -0.006749     -0.872860
# 4               -0.817600                        0.000110     -0.013305
# ..                    ...                             ...           ...
# 95              -0.956159                        0.007184     -0.988713
# 96              -0.895603                        1.229328     -1.188612
# 97               0.005619                        0.005049     -1.158184
# 98              -0.941097                        1.011906      0.008747
# 99               0.006894                        0.000834     -1.238187
#
#     pulley_is_touching_belt  zero_position  cmcouplerfriction  cmdoorfriction  \
# 0                      True       0.008053         110.209282      126.192818
# 1                      True      -0.007868         134.235611      128.355255
# 2                      True       0.798450         131.391937      116.809090
# 3                      True       0.010061         103.441177      119.670959
# 4                      True       0.002982         123.101555      122.323341
# ..                      ...            ...                ...             ...
# 95                     True      -0.001858         124.247215      120.411354
# 96                     True      -0.006611         112.375725      100.365440
# 97                     True      -0.010391         105.921928      147.840225
# 98                     True       0.009548         124.021240      127.678932
# 99                     True       0.009675         124.885811      111.391083
#
#     cmelectronicage  cmvibration  \
# 0          0.828204     0.699365
# 1          0.816811     1.101786
# 2          0.859947     1.003590
# 3          0.986088     0.692654
# 4          0.868561     1.282913
# ..              ...          ...
# 95         0.837673     0.642651
# 96         0.870367     0.662639
# 97         0.777272     0.735214
# 98         0.919250     0.791144
# 99         0.885943     0.899335
#
#                                             doorforce  \
# 0   [-75.22415161132812, -30.140344619750977, 80.3...
# 1   [-74.84675598144531, -29.75479507446289, 84.60...
# 2   [-75.2205810546875, -1.5666511058807373, -8.24...
# 3   [-74.84820556640625, -48.451900482177734, 69.0...
# 4   [-75.34468841552734, -28.379249572753906, 158....
# ..                                                ...
# 95  [-75.3296127319336, -38.99507141113281, 162.47...
# 96  [-74.84461975097656, -32.19388961791992, 184.5...
# 97  [-74.8876724243164, -15.954639434814453, 35.01...
# 98  [-75.2806396484375, -8.197064399719238, 87.721...
# 99  [-75.23292541503906, -15.040507316589355, 101....
#
#                                             doorspeed  \
# 0   [-0.0021178738679736853, 0.09781336784362793, ...
# 1   [0.0025023280177265406, 0.036176204681396484, ...
# 2   [0.002040020190179348, 0.03374751657247543, 0....
# 3   [0.004490987863391638, -0.015736790373921394, ...
# 4   [-0.0017865864792838693, 0.11148208379745483, ...
# ..                                                ...
# 95  [-0.0005667988443747163, 0.09139340370893478, ...
# 96  [-0.002136116148903966, 0.08572884649038315, 0...
# 97  [0.0008074595825746655, 0.10101623088121414, 0...
# 98  [3.562822166713886e-05, 0.0642990916967392, 0....
# 99  [0.0020354243461042643, 0.06143433228135109, 0...
#
#                                          doorposition
# 0   [-0.08953490108251572, -0.0522589236497879, 0....
# 1   [-0.04027137532830238, -0.013830386102199554, ...
# 2   [-0.04053561016917229, -0.05114487186074257, 0...
# 3   [-0.041645705699920654, -0.008244186639785767,...
# 4   [-0.03876642882823944, -0.03420634567737579, 0...
# ..                                                ...
# 95  [-0.08563637733459473, -0.011323708109557629, ...
# 96  [-0.04467852786183357, -0.010350896045565605, ...
# 97  [-0.08199159801006317, 0.008702833205461502, 0...
# 98  [-0.08868646621704102, -0.0018873517401516438,...
# 99  [-0.07297364622354507, 0.00014874862972646952,...
#
# [100 rows x 16 columns]

# %%
comparison_report = train_report.compare(test_report)
comparison_report.to_file("../../results/v6-comparison-profiling_report.html")
# Out:
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\utils\dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
