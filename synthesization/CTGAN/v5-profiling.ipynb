# %% [markdown]
# This script is used to compare the original data with the synthesized data
# The original data is stored in data/preprocessed/group_1.parquet
# The synthesized data is stored in data/synthesized/versuch2/{group_number}.parquet
# The comparison is stored in comparison_versuch{group_number}.html
# Source: https://docs.profiling.ydata.ai/latest/features/comparing_datasets/

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
a = pd.read_parquet(r"../../data/aaa.parquet")
half_df = a.iloc[:80]

train_df = half_df

train_report = ProfileReport(train_df, title="Test")

# %%
atest_df = pd.read_parquet(r"../../data/CompleteDataWithoutCAT_COLS150Epochs.parquet")
test_df = atest_df.iloc[:80]
test_report = ProfileReport(test_df, title="Test")

# %%
comparison_report = train_report.compare(test_report)
comparison_report.to_file("comparison_versuch4.html")
# Out:
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\utils\dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# ...
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\model\pandas\duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 comparison_report = train_report.compare(test_report)
# ----> 2 comparison_report.to_file("comparison_versuch4.html")
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\profile_report.py:370, in ProfileReport.to_file(self, output_file, silent)
#     367         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     368     create_html_assets(self.config, output_file)
# --> 370 data = self.to_html()
#     372 if output_file.suffix != ".html":
#     373     suffix = output_file.suffix
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\profile_report.py:487, in ProfileReport.to_html(self)
#     479 def to_html(self) -> str:
#     480     """Generate and return complete template as lengthy string
#     481         for using with frameworks.
#     482
#    (...)
#     485
#     486     """
# --> 487     return self.html
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\profile_report.py:283, in ProfileReport.html(self)
#     280 @property
#     281 def html(self) -> str:
#     282     if self._html is None:
# --> 283         self._html = self._render_html()
#     284     return self._html
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\profile_report.py:405, in ProfileReport._render_html(self)
#     400 report = self.report
#     402 with tqdm(
#     403     total=1, desc="Render HTML", disable=not self.config.progress_bar
#     404 ) as pbar:
# --> 405     html = HTMLReport(copy.deepcopy(report)).render(
#     406         nav=self.config.html.navbar_show,
#     407         offline=self.config.html.use_local_assets,
#     408         inline=self.config.html.inline,
#     409         assets_prefix=self.config.html.assets_prefix,
#     410         primary_color=self.config.html.style.primary_colors[0],
#     411         logo=self.config.html.style.logo,
#     412         theme=self.config.html.style.theme,
#     413         title=self.description_set.analysis.title,
#     414         date=self.description_set.analysis.date_start,
#     415         version=self.description_set.package["ydata_profiling_version"],
#     416     )
#     418     if self.config.html.minify_html:
#     419         from htmlmin.main import minify
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\report\presentation\flavours\html\root.py:12, in HTMLRoot.render(self, **kwargs)
#       6 def render(self, **kwargs) -> str:
#       7     nav_items = [
#       8         (section.name, section.anchor_id)
#       9         for section in self.content["body"].content["items"]
#      10     ]
# ---> 12     return templates.template("report.html").render(
#      13         **self.content, nav_items=nav_items, **kwargs
#      14     )
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:1301, in Template.render(self, *args, **kwargs)
#    1299     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1300 except Exception:
# -> 1301     self.environment.handle_exception()
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:936, in Environment.handle_exception(self, source)
#     931 """Exception handling helper.  This is used internally to either raise
#     932 rewritten exceptions or return a rendered traceback for the template.
#     933 """
#     934 from .debug import rewrite_traceback_stack
# --> 936 raise rewrite_traceback_stack(source=source)
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\report\presentation\flavours\html\templates\report.html:21, in top-level template code()
#      19 {% endif %}
#      20 <div class="content">
# ---> 21     {{ body.render() }}
#      22 </div>
#      23 {% include 'wrapper/footer.html' %}
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\report\presentation\flavours\html\container.py:28, in HTMLContainer.render(self)
#      22     return templates.template("sequence/select.html").render(
#      23         tabs=self.content["items"],
#      24         anchor_id=self.content["anchor_id"],
#      25         nested=self.content["nested"],
#      26     )
#      27 elif self.sequence_type == "sections":
# ---> 28     return templates.template("sequence/sections.html").render(
#      29         sections=self.content["items"],
#      30         full_width=self.content["full_width"],
#      31     )
#      32 elif self.sequence_type == "grid":
#      33     return templates.template("sequence/grid.html").render(
#      34         items=self.content["items"]
#      35     )
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:1301, in Template.render(self, *args, **kwargs)
#    1299     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1300 except Exception:
# -> 1301     self.environment.handle_exception()
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:936, in Environment.handle_exception(self, source)
#     931 """Exception handling helper.  This is used internally to either raise
#     932 rewritten exceptions or return a rendered traceback for the template.
#     933 """
#     934 from .debug import rewrite_traceback_stack
# --> 936 raise rewrite_traceback_stack(source=source)
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\report\presentation\flavours\html\templates\sequence\sections.html:3, in top-level template code()
#       1 <div class="{% if full_width %}container-fluid{% else %}container{% endif %}">
#       2     {% for section in sections %}
# ----> 3         {% set html = section.render() %}
#       4         {% if html | length > 0 %}
#       5             <div class="row header">
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\report\presentation\flavours\html\container.py:22, in HTMLContainer.render(self)
#      16     return templates.template("sequence/tabs.html").render(
#      17         tabs=self.content["items"],
#      18         anchor_id=self.content["anchor_id"],
#      19         nested=self.content["nested"],
#      20     )
#      21 elif self.sequence_type == "select":
# ---> 22     return templates.template("sequence/select.html").render(
#      23         tabs=self.content["items"],
#      24         anchor_id=self.content["anchor_id"],
#      25         nested=self.content["nested"],
#      26     )
#      27 elif self.sequence_type == "sections":
#      28     return templates.template("sequence/sections.html").render(
#      29         sections=self.content["items"],
#      30         full_width=self.content["full_width"],
#      31     )
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:1301, in Template.render(self, *args, **kwargs)
#    1299     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1300 except Exception:
# -> 1301     self.environment.handle_exception()
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:936, in Environment.handle_exception(self, source)
#     931 """Exception handling helper.  This is used internally to either raise
#     932 rewritten exceptions or return a rendered traceback for the template.
#     933 """
#     934 from .debug import rewrite_traceback_stack
# --> 936 raise rewrite_traceback_stack(source=source)
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\report\presentation\flavours\html\templates\sequence\select.html:35, in top-level template code()
#      33          class="tab-pane col-sm-12{% if loop.first %} active{% endif %}"
#      34          id="{{ anchor_id }}-{{ tab.anchor_id }}">
# ---> 35         {{ tab.render() }}
#      36     </div>
#      37 {% endfor %}
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\ydata_profiling\report\presentation\flavours\html\container.py:22, in HTMLContainer.render(self)
#      16     return templates.template("sequence/tabs.html").render(
#      17         tabs=self.content["items"],
#      18         anchor_id=self.content["anchor_id"],
#      19         nested=self.content["nested"],
#      20     )
#      21 elif self.sequence_type == "select":
# ---> 22     return templates.template("sequence/select.html").render(
#      23         tabs=self.content["items"],
#      24         anchor_id=self.content["anchor_id"],
#      25         nested=self.content["nested"],
#      26     )
#      27 elif self.sequence_type == "sections":
#      28     return templates.template("sequence/sections.html").render(
#      29         sections=self.content["items"],
#      30         full_width=self.content["full_width"],
#      31     )
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:1301, in Template.render(self, *args, **kwargs)
#    1299     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1300 except Exception:
# -> 1301     self.environment.handle_exception()
#
# File e:\m2hycon\Thesis\SyntheticDataGeneration\venv\lib\site-packages\jinja2\environment.py:936, in Environment.handle_exception(self, source)
#     931 """Exception handling helper.  This is used internally to either raise
#     932 rewritten exceptions or return a rendered traceback for the template.
#     933 """
#     934 from .debug import rewrite_traceback_stack
# --> 936 raise rewrite_traceback_stack(source=source)
#
# MemoryError:
